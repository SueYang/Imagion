# %% [markdown]
# ## TO DO
#
# - Delete empty images and add them to clean_dataset folder
# - Figure out how to shuffle by user, rather than by photo, make comparisons within users
# - Figure out how to do proper testing (code to pair up images randomly, predict their score using neural network, and then compare whether the ordinal match was right using our score)
#
# ### TO DO LATER
# - Figure out how to incoroporate regression output
# - Rewrite of code

# %% [markdown]
# ## Create Neural Network

# %%
from keras import applications
from keras.layers import Input, Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.utils import np_utils

# If you want to specify input tensor
input_tensor = Input(shape=(160, 160, 3))
vgg_model = applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_tensor=input_tensor)

# To see the models' architecture and layer names, run the following
vgg_model.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 160, 160, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 160, 160, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 160, 160, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 80, 80, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 80, 80, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 80, 80, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 40, 40, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 40, 40, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Creating dictionary that maps layer names to the layers
layer_dict = dict([(layer.name, layer) for layer in vgg_model.layers])

# Getting output tensor of the last VGG layer that we want to include
x = layer_dict['block4_pool'].output

# Stacking a new simple convolutional network on top of it    
x = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(10, activation='softmax')(x)

# Creating new model. Please note that this is NOT a Sequential() model.
from keras.models import Model
custom_model = Model(inputs=vgg_model.input, outputs=x)

# Make sure that the pre-trained bottom layers are not trainable
for layer in custom_model.layers[:15]:
    layer.trainable = False

# Do not forget to compile it
custom_model.compile(loss='categorical_crossentropy',
                     optimizer='rmsprop',
                     metrics=['accuracy'])

# %% [markdown]
# ## Train Neural Network

# %%
import cv2
import numpy as np
import csv, sqlite3
import math
import os
import random

# %%
"""
Create dictionary with:
Key = filename root
Value = score
"""

con = sqlite3.connect("imagion.db")
cur = con.cursor()

table_cols = [i[0] for i in cur.execute("SELECT * FROM imagion").description]

def get_filenames(): 
    files_dict = {}
    
    cur.execute("SELECT filename, alias, scale_qsc FROM imagion")
    
    count = 0
    
    for file_, alias_, int_score in cur.fetchall():
        if count == 0:
            count += 1
            continue
            
        count += 1 
        
        int_score = int_score - 1
        
        files_dict[file_,alias_] = int_score
        
    return files_dict

files_dict = get_filenames()

# %%
"""Split training and test images"""

PERCENT_TRAINING = 0.75

random.seed(10)
keys = files_dict.keys()
split = int(len(files_dict.keys()) * PERCENT_TRAINING)

random.shuffle(keys) # revisit this shuffle function

#train_keys = keys[:split]
#test_keys = keys[split:]

#print train_keys[1]
#print train_keys[1][1]

seen = []
unique = []
for i in range(len(keys)):
    if keys[i][1] not in seen:
        unique.append(keys[i][1])
    seen.append(keys[i][1])
print len(unique)
print len(seen)

#Counting the number of times each unique name occurs
uni_count = {}
for i in range(len(unique)):
    uni_count[unique[i]] = seen.count(unique[i])
print len(uni_count.values())
print min(uni_count.values())
print max(uni_count.values())

##Pick 250 random users from unique list
test_samp = random.sample(unique, 250)

test_keys = []
train_keys = []
for i in range(len(keys)):
    if keys[i][1] not in test_samp:
        train_keys.append(keys[i][0])
    else:
        test_keys.append(keys[i][0])

print len(test_keys)
print len(train_keys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-15cdca0683af> in <module>()
#       4
#       5 random.seed(10)
# ----> 6 keys = files_dict.keys()
#       7 split = int(len(files_dict.keys()) * PERCENT_TRAINING)
#       8
#
# NameError: name 'files_dict' is not defined

# %%
def chunks(l, n):
    """Yield successive n-sized chunks from l"""
    for i in xrange(0, len(l), n):
        yield l[i:i+n]

# def get_train_data(chunk, img_row, img_col):
#     X_train = []
#     Y_train = []
    
#     try:
#         for imgname in chunk:
#             Y_train.append(files_dict[imgname])
#             filename = 'data_images'+'/'+imgname+'.png'
#             img = cv2.imread(filename)
#             img = cv2.resize(img,(img_row,img_col))
#             X_train.append(img)

#         X_train = np.asarray(X_train)
#         Y_train = np.asarray(Y_train)
        
#         return X_train,Y_train

#     except:
#         X_train=None
#         Y_train=None
#         return X_train,Y_train

def get_train_data(chunk, img_row, img_col):
    X_train = []
    Y_train = []
    
    for imgname in chunk:
        try:
            filename = 'data_images'+'/'+imgname+'.png'
            img = cv2.imread(filename)
            img = cv2.resize(img,(img_row,img_col))
            X_train.append(img)
            Y_train.append(files_dict[imgname])
        except: 
            continue
    X_train = np.asarray(X_train)
    Y_train = np.asarray(Y_train)

    return X_train,Y_train
    
    
    
    
def get_test_data(chunk, img_row, img_col):
    X_test = []
    Y_test = []
    
    for imgname in chunk:
        try:
            filename = './data_images'+'/'+imgname+'.png'
            img = cv2.imread(filename)
            img = cv2.resize(img,(img_row,img_col))
            X_test.append(img)
            Y_test.append(files_dict[imgname])
        except:
            continue
    X_test = np.asarray(X_test)
    Y_test = np.asarray(Y_test)

    return X_test,Y_test

def getTrainData(chunk,nb_classes,img_rows,img_cols):
    X_train,Y_train = get_train_data(chunk,img_rows,img_cols)
    if (X_train!=None and Y_train!=None):
        X_train/=255
    Y_train=np_utils.to_categorical(Y_train, num_classes = 10)
    return (X_train,Y_train)

def getTestData(chunk,nb_classes,img_rows,img_cols):
    X_test,Y_test = get_test_data(chunk,img_rows,img_cols)
    if (X_test!=None and Y_test!=None):
        X_test/=255
    Y_test=np_utils.to_categorical(Y_test, num_classes = 10)
    return (X_test,Y_test)

def test(model, nb_epoch, spatial_test_data, nb_classes, img_rows, img_cols):
    X_test,Y_test = getTestData(test_keys,nb_classes,img_rows,img_cols)
    return (X_test, Y_test)

# %%
## chunk_size = 10
num_epochs = 1
nb_epoch = 50
batch_size = 2
nb_classes = 10
chunk_size = 32
img_rows = 160
img_cols = 160


for e in range(nb_epoch):
    print('-'*40)
    print('Epoch', e)
    print('-'*40)
    print("Training...")
    instance_count=0


    for chunk in chunks(train_keys, chunk_size):
        X_chunk,Y_chunk=getTrainData(chunk,nb_classes,img_rows,img_cols)

        if (X_chunk!=None and Y_chunk!=None):
            #for X_batch, Y_batch in datagen.flow(X_chunk, Y_chunk, batch_size=chunk_size):
            loss = custom_model.fit(X_chunk, Y_chunk, verbose=1, batch_size=batch_size, epochs=num_epochs)
            instance_count+=chunk_size
            print instance_count
            if instance_count%100==0:
                custom_model.save_weights('basic_model.h5',overwrite=True)
# Out:
# ----------------------------------------
# ('Epoch', 0)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 1)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 2)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 3)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 4)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 5)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 6)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 7)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 8)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 9)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 10)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 11)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 12)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 13)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 14)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 15)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 16)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 17)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 18)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 19)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 20)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 21)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 22)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 23)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 24)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 25)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 26)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 27)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 28)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 29)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 30)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 31)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 32)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 33)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 34)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 35)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 36)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 37)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 38)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 39)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 40)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 41)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 42)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 43)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 44)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 45)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 46)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 47)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 48)
# ----------------------------------------
# Training...
# ----------------------------------------
# ('Epoch', 49)
# ----------------------------------------
# Training...

# %%
""" SUDO CODE FOR CUSTOM ACCURACY FUNCTION"""

def test_accuracy(keys):
    count = 0
    accuracy = 0
    
    # select two images randomly
    random.seed(10) 
    random.shuffle(keys.keys()) # revisit shuffle function
    
    # do for same
    
    for x in range(int(len(keys)/2)):
        # get two elements from shuffled dictionary
        key1 = keys.values().pop(0)
        key2 = keys.values().pop(1)
        
        # predict score for each image
        predict1 = custom_model.prediction(key1)
        predict2 = custom_model.prediction(key2)

        # compare whichever predicted score is higher
        max_predict = max(predict1, predict2)

        # compare whichever "score" is higher
        max_actual = max(keys.values()[0], keys.values()[1])

        # check if comparisons match 
        if max_predict == max_actual:
            accuracy +=1

        count += 1
    
    print count, "comparisons made"

    return (accuracy/count)

# %%
import random

random.sample(files_dict.keys(), 2)
# Out:
# [u'galagonzalez_0', u'fluffypack_8']

# %%
files_dict.keys()
# Out:
# [u'uolesporte_1',
#  u'archilovers_16',
#  u'hairgod_zito_15',
#  u'archilovers_14',
#  u'archilovers_15',
#  u'archilovers_12',
#  u'archilovers_13',
#  u'archilovers_10',
#  u'archilovers_11',
#  u'uolesporte_7',
#  u'kitkat_ch_0',
#  u'vacationwolf_12',
#  u'kochifaraj_10',
#  u'thefashionguitar_1',
#  u'nadiadamaso_ebnl_10',
#  u'uolesporte_9',
#  u'badasscassfit__13',
#  u'badasscassfit__12',
#  u'badasscassfit__11',
#  u'badasscassfit__10',
#  u'badasscassfit__15',
#  u'badasscassfit__14',
#  u'ashybines_14',
#  u'ashybines_15',
#  u'ashybines_10',
#  u'ashybines_11',
#  u'ashybines_12',
#  u'ashybines_13',
#  u'raffinagita1717_7',
#  u'streetsfashions_2',
#  u'marioncameleon_3',
#  u'hairgod_zito_14',
#  u'marioncameleon_1',
#  u'marioncameleon_0',
#  u'marioncameleon_7',
#  u'marioncameleon_6',
#  u'marioncameleon_5',
#  u'marioncameleon_4',
#  u'kochifaraj_16',
#  u'marioncameleon_9',
#  u'marioncameleon_8',
#  u'sonchicc_15',
#  u'lioninthewild_15',
#  u'riverviiperi_0',
#  u'samblacky_9',
#  u'samblacky_8',
#  u'samblacky_5',
#  u'hairgod_zito_10',
#  u'samblacky_7',
#  u'samblacky_6',
#  u'samblacky_1',
#  u'samblacky_0',
#  u'samblacky_3',
#  u'hairgod_zito_11',
#  u'mevy_10',
#  u'hairgod_zito_12',
#  u'kochifaraj_15',
#  u'mevy_11',
#  u'hairgod_zito_13',
#  u'mevy_12',
#  u'lioninthewild_16',
#  u'thevisualscollective_12',
#  u'mevy_13',
#  u'nadiadamaso_ebnl_15',
#  u'mevy_14',
#  u'riverviiperi_9',
#  u'stylizimoblog_6',
#  u'sergiocarlo_9',
#  u'riverviiperi_8',
#  u'kochifaraj_14',
#  u'mevy_16',
#  u'stylizimoblog_7',
#  u'ovunno_6',
#  u'bibbideg_16',
#  u'bibbideg_15',
#  u'bibbideg_14',
#  u'bibbideg_13',
#  u'bibbideg_12',
#  u'bibbideg_11',
#  u'bibbideg_10',
#  u'nadiadamaso_ebnl_14',
#  u'stylizimoblog_2',
#  u'stylizimoblog_3',
#  u'elliottsailors_1',
#  u'elliottsailors_0',
#  u'audi_obsession_8',
#  u'audi_obsession_9',
#  u'elliottsailors_5',
#  u'elliottsailors_4',
#  u'elliottsailors_7',
#  u'elliottsailors_6',
#  u'_tinamaria_12',
#  u'_tinamaria_13',
#  u'_tinamaria_10',
#  u'_tinamaria_11',
#  u'_tinamaria_16',
#  u'audi_obsession_7',
#  u'_tinamaria_14',
#  u'_tinamaria_15',
#  u'shonephoto_8',
#  u'shonephoto_9',
#  u'ovunno_7',
#  u'nadiadamaso_ebnl_16',
#  u'fashion_by_gi_9',
#  u'fashion_by_gi_8',
#  u'hotdudesreading_11',
#  u'ulyana.aster_8',
#  u'bestofstreetstyled_12',
#  u'bestofstreetstyled_13',
#  u'bestofstreetstyled_10',
#  u'bestofstreetstyled_11',
#  u'bestofstreetstyled_16',
#  u'fashion_by_gi_4',
#  u'bestofstreetstyled_14',
#  u'bestofstreetstyled_15',
#  u'ovunno_4',
#  u'sheikeandco_9',
#  u'lovelypepa_12',
#  u'lovelypepa_13',
#  u'lovelypepa_10',
#  u'lovelypepa_11',
#  u'lovelypepa_16',
#  u'sneakernews_9',
#  u'lovelypepa_14',
#  u'lovelypepa_15',
#  u'sneakernews_4',
#  u'sneakernews_5',
#  u'sneakernews_6',
#  u'sneakernews_7',
#  u'sneakernews_0',
#  u'sneakernews_1',
#  u'sneakernews_2',
#  u'sneakernews_3',
#  u'rezaphotography_8',
#  u'ovunno_5',
#  u'vutheara_15',
#  u'vutheara_14',
#  u'averagerob_13',
#  u'averagerob_12',
#  u'averagerob_11',
#  u'averagerob_10',
#  u'gkstories_13',
#  u'gkstories_12',
#  u'averagerob_15',
#  u'averagerob_14',
#  u'vutheara_16',
#  u'vegancommunity_7',
#  u'vegancommunity_6',
#  u'vegancommunity_5',
#  u'vegancommunity_4',
#  u'vegancommunity_3',
#  u'vegancommunity_2',
#  u'vegancommunity_1',
#  u'vegancommunity_0',
#  u'twallisch_15',
#  u'ovunno_3',
#  u'vegancommunity_8',
#  u'7ikhals_9',
#  u'7ikhals_8',
#  u'7ikhals_5',
#  u'7ikhals_4',
#  u'7ikhals_7',
#  u'7ikhals_6',
#  u'7ikhals_1',
#  u'7ikhals_0',
#  u'7ikhals_3',
#  u'7ikhals_2',
#  u'madwhips_bimmer_10',
#  u'madwhips_bimmer_11',
#  u'twallisch_14',
#  u'strictlyweddings_10',
#  u'ovunno_0',
#  u'misswinter_16',
#  u'luckybsmith_7',
#  u'luckybsmith_6',
#  u'brigadeirochoc_8',
#  u'brigadeirochoc_9',
#  u'luckybsmith_3',
#  u'luckybsmith_2',
#  u'luckybsmith_1',
#  u'gypsea_lust_1',
#  u'brigadeirochoc_2',
#  u'brigadeirochoc_3',
#  u'brigadeirochoc_0',
#  u'brigadeirochoc_1',
#  u'brigadeirochoc_6',
#  u'brigadeirochoc_7',
#  u'brigadeirochoc_4',
#  u'brigadeirochoc_5',
#  u'strictlyweddings_11',
#  u'ovunno_1',
#  u'worldwanderlust_16',
#  u'worldwanderlust_15',
#  u'worldwanderlust_14',
#  u'worldwanderlust_13',
#  u'worldwanderlust_12',
#  u'worldwanderlust_11',
#  u'vacationwolf_13',
#  u'theworldguru_1',
#  u'sheidlina_6',
#  u'cozinhadalbo_11',
#  u'cozinhadalbo_10',
#  u'cozinhadalbo_13',
#  u'cozinhadalbo_12',
#  u'cozinhadalbo_15',
#  u'cozinhadalbo_14',
#  u'theworldguru_0',
#  u'cozinhadalbo_16',
#  u'misselvani_10',
#  u'misselvani_11',
#  u'misselvani_12',
#  u'misselvani_13',
#  u'lipstickfables_11',
#  u'lipstickfables_10',
#  u'lipstickfables_13',
#  u'lipstickfables_12',
#  u'lipstickfables_15',
#  u'lipstickfables_14',
#  u'lipstickfables_16',
#  u'lyzabeth_lopez_7',
#  u'theworldguru_7',
#  u'whiteaddicted_9',
#  u'marioncameleon_16',
#  u'marioncameleon_15',
#  u'marioncameleon_14',
#  u'marioncameleon_13',
#  u'marioncameleon_12',
#  u'marioncameleon_11',
#  u'marioncameleon_10',
#  u'theworldguru_6',
#  u'whiteaddicted_8',
#  u'micahgianneli_1',
#  u'kilianjornet_0',
#  u'annijor_9',
#  u'annijor_8',
#  u'yuyacst_3',
#  u'annijor_3',
#  u'annijor_2',
#  u'annijor_1',
#  u'annijor_0',
#  u'annijor_7',
#  u'annijor_6',
#  u'annijor_5',
#  u'annijor_4',
#  u'theworldguru_5',
#  u'thesheerconnection_5',
#  u'thesheerconnection_4',
#  u'timethai_1',
#  u'thesheerconnection_7',
#  u'heidimakeupartist_1',
#  u'belenhostalet_4',
#  u'heidimakeupartist_3',
#  u'heidimakeupartist_2',
#  u'heidimakeupartist_5',
#  u'heidimakeupartist_4',
#  u'heidimakeupartist_7',
#  u'belenhostalet_5',
#  u'heidimakeupartist_9',
#  u'heidimakeupartist_8',
#  u'andy_mann_11',
#  u'theworldguru_4',
#  u'thesheerconnection_0',
#  u'seacannon_4',
#  u'andy_mann_10',
#  u'thesheerconnection_3',
#  u'marioncameleon_2',
#  u'frenchwords_13',
#  u'thesheerconnection_2',
#  u'andy_mann_16',
#  u'yuyacst_1',
#  u'belenhostalet_2',
#  u'belenhostalet_3',
#  u'paollaoliveirareal_14',
#  u'thesheerconnection_14',
#  u'thesheerconnection_8',
#  u'brianskerry_8',
#  u'brianskerry_9',
#  u'brianskerry_4',
#  u'brianskerry_5',
#  u'brianskerry_6',
#  u'brianskerry_7',
#  u'brianskerry_0',
#  u'brianskerry_1',
#  u'brianskerry_2',
#  u'brianskerry_3',
#  u'louisdarcis_7',
#  u'maryamnyc_10',
#  u'yuyacst_7',
#  u'mikeleceppi_13',
#  u'kyrenian_11',
#  u'paollaoliveirareal_16',
#  u'micahgianneli_4',
#  u'roofusandkilo_9',
#  u'maryamnyc_13',
#  u'filippofiora_11',
#  u'filippofiora_10',
#  u'filippofiora_13',
#  u'filippofiora_12',
#  u'filippofiora_15',
#  u'filippofiora_14',
#  u'filippofiora_16',
#  u'paollaoliveirareal_11',
#  u'mentorofthebillion_6',
#  u'secdus_14',
#  u'maryamnyc_12',
#  u'secdus_12',
#  u'secdus_13',
#  u'secdus_10',
#  u'secdus_11',
#  u'piques_14',
#  u'piques_15',
#  u'piques_16',
#  u'piques_10',
#  u'piques_11',
#  u'piques_12',
#  u'piques_13',
#  u'paollaoliveirareal_10',
#  u'samblacky_4',
#  u'mentorofthebillion_1',
#  u'maryamnyc_15',
#  u'nadiadamaso_ebnl_4',
#  u'nadiadamaso_ebnl_7',
#  u'nadiadamaso_ebnl_6',
#  u'paollaoliveirareal_13',
#  u'mentorofthebillion_0',
#  u'samblacky_2',
#  u'meganhess_official_4',
#  u'maryamnyc_14',
#  u'zacsmithfitness_4',
#  u'nadiadamaso_ebnl_3',
#  u'chris_sharma_11',
#  u'chris_sharma_10',
#  u'chris_sharma_13',
#  u'chris_sharma_12',
#  u'chris_sharma_15',
#  u'chris_sharma_14',
#  u'chris_sharma_16',
#  u'dani_thorne_5',
#  u'dani_thorne_4',
#  u'dani_thorne_7',
#  u'dani_thorne_6',
#  u'dani_thorne_1',
#  u'dani_thorne_0',
#  u'dani_thorne_3',
#  u'dani_thorne_2',
#  u'alexisren_11',
#  u'alexisren_10',
#  u'alexisren_13',
#  u'alexisren_12',
#  u'alexisren_15',
#  u'alexisren_14',
#  u'alexisren_16',
#  u'bestofstreetstyled_0',
#  u'bestofstreetstyled_1',
#  u'bestofstreetstyled_2',
#  u'bestofstreetstyled_3',
#  u'bestofstreetstyled_4',
#  u'bestofstreetstyled_5',
#  u'bestofstreetstyled_6',
#  u'bestofstreetstyled_7',
#  u'bestofstreetstyled_8',
#  u'bestofstreetstyled_9',
#  u'shoutmysneakz_10',
#  u'nadiadamaso_ebnl_8',
#  u'petitesluxures_13',
#  u'petitesluxures_12',
#  u'kpunkka_3',
#  u'petitesluxures_11',
#  u'r.h.sin_13',
#  u'nude_yogagirl_5',
#  u'nude_yogagirl_4',
#  u'nude_yogagirl_7',
#  u'nude_yogagirl_6',
#  u'nude_yogagirl_1',
#  u'nude_yogagirl_0',
#  u'nude_yogagirl_3',
#  u'nude_yogagirl_2',
#  u'r.h.sin_11',
#  u'nude_yogagirl_9',
#  u'nude_yogagirl_8',
#  u'petitesluxures_16',
#  u'3ala2o_5',
#  u'3ala2o_4',
#  u'3ala2o_7',
#  u'3ala2o_6',
#  u'3ala2o_1',
#  u'3ala2o_0',
#  u'3ala2o_3',
#  u'3ala2o_2',
#  u'petitesluxures_14',
#  u'3ala2o_9',
#  u'3ala2o_8',
#  u'brianskerry_16',
#  u'enjoyphoenix_14',
#  u'brianskerry_14',
#  u'brianskerry_15',
#  u'brianskerry_12',
#  u'brianskerry_13',
#  u'brianskerry_10',
#  u'brianskerry_11',
#  u'soysaludable_15',
#  u'arc.only_3',
#  u'arc.only_2',
#  u'arc.only_1',
#  u'arc.only_0',
#  u'arc.only_7',
#  u'arc.only_6',
#  u'arc.only_5',
#  u'arc.only_4',
#  u'arc.only_9',
#  u'arc.only_8',
#  u'soysaludable_14',
#  u'thisisamans.world_1',
#  u'vexx_art_8',
#  u'vexx_art_9',
#  u'vexx_art_6',
#  u'vexx_art_7',
#  u'vexx_art_4',
#  u'vexx_art_5',
#  u'vexx_art_2',
#  u'vexx_art_3',
#  u'vexx_art_0',
#  u'vexx_art_1',
#  u'zachallia_8',
#  u'willamazing_9',
#  u'ciriljazbec_2',
#  u'ciriljazbec_3',
#  u'ciriljazbec_0',
#  u'ciriljazbec_1',
#  u'ciriljazbec_6',
#  u'ciriljazbec_7',
#  u'ciriljazbec_4',
#  u'ciriljazbec_5',
#  u'elensham_14',
#  u'elensham_15',
#  u'elensham_16',
#  u'ciriljazbec_9',
#  u'elensham_10',
#  u'elensham_11',
#  u'elensham_12',
#  u'elensham_13',
#  u'zachallia_3',
#  u'meryturiel_1',
#  u'soysaludable_16',
#  u'zachallia_2',
#  u'zachallia_1',
#  u'deemabayyaa_3',
#  u'streetsfashions_4',
#  u'zachallia_0',
#  u'deemabayyaa_2',
#  u'williamjardell_9',
#  u'deemabayyaa_1',
#  u'zachallia_6',
#  u'meryturiel_0',
#  u'aliona_hilt_5',
#  u'adesignersmind_8',
#  u'adesignersmind_9',
#  u'adesignersmind_4',
#  u'adesignersmind_5',
#  u'adesignersmind_6',
#  u'adesignersmind_7',
#  u'adesignersmind_0',
#  u'adesignersmind_1',
#  u'adesignersmind_2',
#  u'adesignersmind_3',
#  u'carolsaraivafitness_10',
#  u'carolsaraivafitness_11',
#  u'carolsaraivafitness_12',
#  u'carolsaraivafitness_13',
#  u'carolsaraivafitness_14',
#  u'aliona_hilt_0',
#  u'carolsaraivafitness_16',
#  u'everlook_photography_9',
#  u'everlook_photography_6',
#  u'everlook_photography_7',
#  u'everlook_photography_4',
#  u'everlook_photography_5',
#  u'everlook_photography_2',
#  u'everlook_photography_3',
#  u'everlook_photography_0',
#  u'everlook_photography_1',
#  u'insideweddings_14',
#  u'insideweddings_15',
#  u'insideweddings_16',
#  u'insideweddings_10',
#  u'insideweddings_11',
#  u'insideweddings_12',
#  u'insideweddings_13',
#  u'lyzabethlopez_15',
#  u'lyzabethlopez_14',
#  u'lyzabethlopez_11',
#  u'deemabayyaa_9',
#  u'lyzabethlopez_13',
#  u'lyzabethlopez_12',
#  u'deemabayyaa_8',
#  u'vanlifers_15',
#  u'sonchicc_0',
#  u'meryturiel_2',
#  u'thesheerconnection_11',
#  u'andreamelchiorre1_12',
#  u'andreamelchiorre1_13',
#  u'andreamelchiorre1_10',
#  u'andreamelchiorre1_11',
#  u'andreamelchiorre1_16',
#  u'cristinamittermeier_2',
#  u'andreamelchiorre1_14',
#  u'andreamelchiorre1_15',
#  u'aliona_hilt_9',
#  u'withlovekarissa_6',
#  u'puanindya_1',
#  u'der_landgraf_6',
#  u'der_landgraf_7',
#  u'der_landgraf_4',
#  u'der_landgraf_5',
#  u'der_landgraf_2',
#  u'der_landgraf_3',
#  u'der_landgraf_0',
#  u'der_landgraf_1',
#  u'puanindya_7',
#  u'der_landgraf_8',
#  u'der_landgraf_9',
#  u'puanindya_5',
#  u'wildcoyphotography_0',
#  u'mauricetravelphotos_6',
#  u'puanindya_4',
#  u'paulinhohop_5',
#  u'paulinhohop_4',
#  u'meryturiel_4',
#  u'paulinhohop_7',
#  u'sondos_aq_15',
#  u'paulinhohop_6',
#  u'theradavist_4',
#  u'zhanna_badoeva_1',
#  u'paulinhohop_1',
#  u'puanindya_15',
#  u'puanindya_14',
#  u'puanindya_13',
#  u'puanindya_12',
#  u'puanindya_11',
#  u'paulinhohop_0',
#  u'paulinhohop_3',
#  u'meryturiel_7',
#  u'supercarlifestyle_5',
#  u'paulinhohop_2',
#  u'elliottsailors_3',
#  u'elliottsailors_2',
#  u'zhanna_badoeva_6',
#  u'iartos_13',
#  u'iartos_12',
#  u'iartos_11',
#  u'iartos_10',
#  u'meryturiel_6',
#  u'everlook_photography_14',
#  u'everlook_photography_15',
#  u'everlook_photography_16',
#  u'everlook_photography_10',
#  u'everlook_photography_11',
#  u'everlook_photography_12',
#  u'everlook_photography_13',
#  u'd.signers_15',
#  u'elliottsailors_9',
#  u'd.signers_16',
#  u'd.signers_11',
#  u'd.signers_10',
#  u'd.signers_13',
#  u'elliottsailors_8',
#  u'flamuruk_14',
#  u'flamuruk_15',
#  u'flamuruk_10',
#  u'audi_obsession_0',
#  u'flamuruk_12',
#  u'flamuruk_13',
#  u'massy.arias_14',
#  u'audi_obsession_1',
#  u'swaypaul_11',
#  u'berlinstagram_11',
#  u'audi_obsession_6',
#  u'berlinstagram_13',
#  u'berlinstagram_12',
#  u'berlinstagram_15',
#  u'berlinstagram_14',
#  u'theradavist_1',
#  u'berlinstagram_16',
#  u'marcelfloruss_6',
#  u'marcelfloruss_7',
#  u'marcelfloruss_4',
#  u'marcelfloruss_5',
#  u'marcelfloruss_2',
#  u'audi_obsession_4',
#  u'marcelfloruss_0',
#  u'marcelfloruss_1',
#  u'doina_11',
#  u'doina_10',
#  u'doina_13',
#  u'audi_obsession_5',
#  u'doina_15',
#  u'doina_14',
#  u'joselyncano_15',
#  u'doina_16',
#  u'teamfk_9',
#  u'teamfk_8',
#  u'teamfk_7',
#  u'teamfk_6',
#  u'teamfk_5',
#  u'teamfk_4',
#  u'teamfk_3',
#  u'teamfk_2',
#  u'teamfk_1',
#  u'teamfk_0',
#  u'seanopry55_12',
#  u'seanopry55_13',
#  u'seanopry55_10',
#  u'seanopry55_11',
#  u'seanopry55_16',
#  u'seanopry55_14',
#  u'seanopry55_15',
#  u'stefaniegoldmarie_10',
#  u'mia_astral_6',
#  u'pinkperception_7',
#  u'mia_astral_7',
#  u'theradavist_3',
#  u'mia_astral_4',
#  u'leagueofupdates_14',
#  u'minilicious_6',
#  u'minilicious_5',
#  u'mia_astral_5',
#  u'leagueofupdates_10',
#  u'leagueofupdates_11',
#  u'leagueofupdates_12',
#  u'leagueofupdates_13',
#  u'yarasantosoficial_6',
#  u'michaelmelford_15',
#  u'yarasantosoficial_4',
#  u'rumineely_4',
#  u'yarasantosoficial_2',
#  u'yarasantosoficial_3',
#  u'minilicious_9',
#  u'linda_lomelino_16',
#  u'doctor.mike_9',
#  u'doctor.mike_8',
#  u'mia_astral_0',
#  u'doctor.mike_3',
#  u'doctor.mike_2',
#  u'doctor.mike_1',
#  u'doctor.mike_0',
#  u'doctor.mike_7',
#  u'doctor.mike_6',
#  u'doctor.mike_5',
#  u'doctor.mike_4',
#  u'victoriarpro_8',
#  u'hawkeyehuey_9',
#  u'hawkeyehuey_8',
#  u'hawkeyehuey_5',
#  u'hawkeyehuey_4',
#  u'hawkeyehuey_7',
#  u'hawkeyehuey_6',
#  u'hawkeyehuey_1',
#  u'hawkeyehuey_0',
#  u'hawkeyehuey_3',
#  u'hawkeyehuey_2',
#  u'charlestrippy_10',
#  u'charlestrippy_11',
#  u'charlestrippy_12',
#  u'charlestrippy_13',
#  u'charlestrippy_14',
#  u'charlestrippy_15',
#  u'charlestrippy_16',
#  u'seacannon_5',
#  u'supercarlifestyle_3',
#  u'restless.arch_4',
#  u'shannakress83_10',
#  u'makaniterror_16',
#  u'sashaspilberg_9',
#  u'makaniterror_14',
#  u'makaniterror_15',
#  u'makaniterror_12',
#  u'makaniterror_13',
#  u'makaniterror_10',
#  u'makaniterror_11',
#  u'victoriarpro_7',
#  u'victoriarpro_6',
#  u'victoriarpro_4',
#  u'lane_toran_16',
#  u'lane_toran_14',
#  u'lane_toran_15',
#  u'lane_toran_12',
#  u'lane_toran_13',
#  u'lane_toran_10',
#  u'lane_toran_11',
#  u'belenhostalet_16',
#  u'seacannon_0',
#  u'belenhostalet_14',
#  u'belenhostalet_15',
#  u'belenhostalet_12',
#  u'belenhostalet_13',
#  u'belenhostalet_10',
#  u'belenhostalet_11',
#  u'seacannon_1',
#  u'amytoensing_0',
#  u'amytoensing_1',
#  u'amytoensing_2',
#  u'amytoensing_3',
#  u'amytoensing_4',
#  u'amytoensing_5',
#  u'amytoensing_6',
#  u'amytoensing_7',
#  u'amytoensing_8',
#  u'amytoensing_9',
#  u'withhearts_7',
#  u'fashion_by_gi_1',
#  u'fashion_by_gi_0',
#  u'italy.vacations_14',
#  u'fashion_by_gi_3',
#  u'fashion_by_gi_2',
#  u'fashion_by_gi_5',
#  u'andyheart_14',
#  u'andyheart_15',
#  u'andyheart_16',
#  u'andyheart_10',
#  u'andyheart_11',
#  u'andyheart_12',
#  u'andyheart_13',
#  u'fashion_by_gi_6',
#  u'instasurreal_14',
#  u'aureta_5',
#  u'aureta_4',
#  u'aureta_7',
#  u'aureta_6',
#  u'aureta_1',
#  u'aureta_0',
#  u'aureta_3',
#  u'aureta_2',
#  u'thefatjewish_9',
#  u'aureta_9',
#  u'aureta_8',
#  u'sondos_aq_1',
#  u'brunaviolamt_11',
#  u'sondos_aq_3',
#  u'sondos_aq_2',
#  u'sondos_aq_5',
#  u'sondos_aq_4',
#  u'sondos_aq_7',
#  u'brunaviolamt_10',
#  u'sondos_aq_9',
#  u'sondos_aq_8',
#  u'instasurreal_15',
#  u'_picolo_14',
#  u'_picolo_13',
#  u'_picolo_12',
#  u'_picolo_11',
#  u'_picolo_10',
#  u'destination_wow_11',
#  u'brunaviolamt_15',
#  u'joselyncano_13',
#  u'johnstanmeyer_14',
#  u'alexmidler_10',
#  u'alexmidler_11',
#  u'alexmidler_12',
#  u'alexmidler_13',
#  u'alexmidler_14',
#  u'alexmidler_15',
#  u'alexmidler_16',
#  u'margaret__zhang_7',
#  u'margaret__zhang_6',
#  u'margaret__zhang_5',
#  u'margaret__zhang_4',
#  u'margaret__zhang_3',
#  u'margaret__zhang_2',
#  u'margaret__zhang_1',
#  u'kardinalmelon_16',
#  u'margaret__zhang_9',
#  u'margaret__zhang_8',
#  u'sergiocarvajal7_10',
#  u'michaelmelford_11',
#  u'gerdludwig_11',
#  u'gerdludwig_10',
#  u'gerdludwig_12',
#  u'sergiocarvajal7_12',
#  u'sergiocarvajal7_13',
#  u'swisswatches_2',
#  u'puanindya_3',
#  u'theradavist_15',
#  u'sergiocarvajal7_14',
#  u'theradavist_16',
#  u'theradavist_11',
#  u'theradavist_10',
#  u'theradavist_13',
#  u'sergiocarvajal7_15',
#  u'bejamin_8',
#  u'bejamin_9',
#  u'bejamin_0',
#  u'bejamin_1',
#  u'bejamin_2',
#  u'bejamin_3',
#  u'bejamin_4',
#  u'bejamin_5',
#  u'bejamin_6',
#  u'bejamin_7',
#  u'movifiedbollywood_10',
#  u'movifiedbollywood_11',
#  u'movifiedbollywood_12',
#  u'movifiedbollywood_13',
#  u'movifiedbollywood_14',
#  u'movifiedbollywood_15',
#  u'movifiedbollywood_16',
#  u'michaelmelford_13',
#  u'theplanetd_14',
#  u'missalena.92_15',
#  u'missalena.92_14',
#  u'afnan_albatel_12',
#  u'afnan_albatel_13',
#  u'afnan_albatel_10',
#  u'afnan_albatel_11',
#  u'afnan_albatel_16',
#  u'afnan_albatel_14',
#  u'afnan_albatel_15',
#  u'johnstanmeyer_10',
#  u'missalena.92_16',
#  u'missalena.92_11',
#  u'michaelmelford_12',
#  u'missalena.92_10',
#  u'deliscake_9',
#  u'deliscake_8',
#  u'ideas_tatoo_14',
#  u'ideas_tatoo_15',
#  u'ideas_tatoo_12',
#  u'ideas_tatoo_13',
#  u'ideas_tatoo_10',
#  u'ideas_tatoo_11',
#  u'deliscake_1',
#  u'deliscake_0',
#  u'deliscake_3',
#  u'deliscake_2',
#  u'deliscake_5',
#  u'deliscake_4',
#  u'deliscake_7',
#  u'deliscake_6',
#  u'afofa_11',
#  u'afofa_10',
#  u'afofa_13',
#  u'afofa_12',
#  u'afofa_15',
#  u'afofa_14',
#  u'ronan_donovan_9',
#  u'michaelchristopherbrown_8',
#  u'michaelchristopherbrown_9',
#  u'mia_astral_3',
#  u'pilotpatric_1',
#  u'twinkleintrendz_5',
#  u'bryceyoga_16',
#  u'bryceyoga_15',
#  u'bryceyoga_14',
#  u'bryceyoga_13',
#  u'bryceyoga_12',
#  u'bryceyoga_11',
#  u'bryceyoga_10',
#  u'donnahaymagazine_16',
#  u'donnahaymagazine_15',
#  u'donnahaymagazine_14',
#  u'donnahaymagazine_13',
#  u'donnahaymagazine_12',
#  u'donnahaymagazine_11',
#  u'donnahaymagazine_10',
#  u'sea_see_you_5',
#  u'sea_see_you_4',
#  u'sea_see_you_7',
#  u'michaelchristopherbrown_1',
#  u'sea_see_you_1',
#  u'sea_see_you_0',
#  u'sea_see_you_3',
#  u'sea_see_you_2',
#  u'icandyfitbeauty_5',
#  u'sea_see_you_9',
#  u'sea_see_you_8',
#  u'icandyfitbeauty_4',
#  u'evakosmasflores_15',
#  u'evakosmasflores_14',
#  u'evakosmasflores_16',
#  u'evakosmasflores_11',
#  u'evakosmasflores_10',
#  u'evakosmasflores_13',
#  u'evakosmasflores_12',
#  u'icandyfitbeauty_6',
#  u'sondos_aq_10',
#  u'archixxi_15',
#  u'archixxi_14',
#  u'archixxi_16',
#  u'archixxi_11',
#  u'archixxi_10',
#  u'archixxi_13',
#  u'archixxi_12',
#  u'paigehathaway_8',
#  u'princepelayo_0',
#  u'paigehathaway_7',
#  u'princepelayo_2',
#  u'princepelayo_3',
#  u'princepelayo_4',
#  u'princepelayo_5',
#  u'princepelayo_6',
#  u'paigehathaway_6',
#  u'princepelayo_8',
#  u'princepelayo_9',
#  u'paigehathaway_5',
#  u'michelle_lewin_8',
#  u'ronan_donovan_2',
#  u'paigehathaway_4',
#  u'gkstories_16',
#  u'romaincolin_15',
#  u'paigehathaway_3',
#  u'romaincolin_16',
#  u'romaincolin_11',
#  u'gkstories_15',
#  u'romaincolin_13',
#  u'paigehathaway_2',
#  u'gkstories_14',
#  u'paigehathaway_1',
#  u'pilotpatric_4',
#  u'paigehathaway_0',
#  u'ronan_donovan_3',
#  u'gkstories_11',
#  u'gkstories_10',
#  u'deliciouslyella_16',
#  u'michelle_lewin_0',
#  u'deliciouslyella_14',
#  u'deliciouslyella_15',
#  u'deliciouslyella_12',
#  u'deliciouslyella_13',
#  u'deliciouslyella_10',
#  u'deliciouslyella_11',
#  u'thomaspeschak_8',
#  u'michelle_lewin_2',
#  u'xeniaoverdose_4',
#  u'blogilates_1',
#  u'blogilates_0',
#  u'blogilates_3',
#  u'blogilates_2',
#  u'blogilates_5',
#  u'blogilates_4',
#  u'blogilates_7',
#  u'blogilates_6',
#  u'blogilates_9',
#  u'blogilates_8',
#  u'daddyissues__0',
#  u'daddyissues__1',
#  u'daddyissues__6',
#  u'daddyissues__7',
#  u'daddyissues__4',
#  u'daddyissues__5',
#  u'natlustosa_5',
#  u'natlustosa_4',
#  u'natlustosa_7',
#  u'natlustosa_6',
#  u'natlustosa_1',
#  u'michelle_lewin_6',
#  u'natlustosa_3',
#  u'natlustosa_2',
#  u'michelle_lewin_7',
#  u'natlustosa_9',
#  u'natlustosa_8',
#  u'meganhess_official_5',
#  u'pilotpatric_9',
#  u'prettyfrowns_13',
#  u'kewiki_5',
#  u'kewiki_4',
#  u'kewiki_7',
#  u'kewiki_6',
#  u'kewiki_1',
#  u'kewiki_0',
#  u'kewiki_3',
#  u'kewiki_2',
#  u'hosico_cat_11',
#  u'hosico_cat_10',
#  u'hosico_cat_13',
#  u'hosico_cat_12',
#  u'kewiki_9',
#  u'hosico_cat_14',
#  u'pilotpatric_8',
#  u'worldwanderlust_6',
#  u'theradavist_5',
#  u'solelynikes_14',
#  u'vegancommunity_9',
#  u'faheeym_14',
#  u'theradavist_7',
#  u'doyoutravel_16',
#  u'alissaviolet_4',
#  u'alissaviolet_7',
#  u'alissaviolet_6',
#  u'alissaviolet_1',
#  u'alissaviolet_0',
#  u'alissaviolet_3',
#  u'alissaviolet_2',
#  u'angelicablick_13',
#  u'cravingsinamsterdam_14',
#  u'alissaviolet_9',
#  u'alissaviolet_8',
#  u'cravingsinamsterdam_10',
#  u'cravingsinamsterdam_11',
#  u'whatmyboyfriendwore_1',
#  u'ronan_donovan_5',
#  u'faheeym_13',
#  ...]

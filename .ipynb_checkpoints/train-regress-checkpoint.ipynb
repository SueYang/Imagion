# %% [markdown]
# ## TO DO
#
# - Delete empty images and add them to clean_dataset folder [DONE]
# - Figure out how to shuffle by user, rather than by photo, make comparisons within users [DONE]
# - Figure out how to do proper testing (code to pair up images randomly, predict their score using neural network, and then compare whether the ordinal match was right using our score) [DONE]
#
# - Change training code to pull only images from new training set
#
# ### TO DO LATER
# - Figure out how to incoroporate regression output
# - Rewrite of code

# %% [markdown]
# ## Create Neural Network

# %%
from keras import applications, optimizers
from keras.layers import Input, Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras.utils import np_utils

# If you want to specify input tensor
input_tensor = Input(shape=(160, 160, 3))
vgg_model = applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_tensor=input_tensor)

# To see the models' architecture and layer names, run the following
vgg_model.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 160, 160, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 160, 160, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 160, 160, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 80, 80, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 80, 80, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 80, 80, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 40, 40, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 40, 40, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 10, 10, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 5, 5, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Creating dictionary that maps layer names to the layers
layer_dict = dict([(layer.name, layer) for layer in vgg_model.layers])

# Getting output tensor of the last VGG layer that we want to include
x = layer_dict['block4_pool'].output

# Stacking a new simple convolutional network on top of it    
x = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1)(x)

# Creating new model. Please note that this is NOT a Sequential() model.
from keras.models import Model
custom_model = Model(inputs=vgg_model.input, outputs=x)

# Make sure that the pre-trained bottom layers are not trainable
for layer in custom_model.layers[:15]:
    layer.trainable = False

# Custom Optimizer    
opt = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=1e-6)

# Do not forget to compile it
custom_model.compile(loss='mse',
                     optimizer=opt,
                     metrics=['accuracy'])

# %%
custom_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 160, 160, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 160, 160, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 160, 160, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 80, 80, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 80, 80, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 80, 80, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 40, 40, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 40, 40, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 40, 40, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 20, 20, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 20, 20, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 20, 20, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 10, 10, 512)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 64)          294976
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 8,192,897
# Trainable params: 557,633
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %% [markdown]
# ## Train Neural Network

# %%
import cv2
import numpy as np
import csv, sqlite3
import math
import os
import random

# %%
"""
Create dictionary with:
Key = filename root
Value = score
"""

con = sqlite3.connect("imagion.db")
cur = con.cursor()

table_cols = [i[0] for i in cur.execute("SELECT * FROM scores").description]

def get_filenames(): 
    files_dict = {}
    
    cur.execute("SELECT filename, norm_score FROM scores")
    
    count = 0
    
    for file_, score in cur.fetchall():
        if count == 0:
            count += 1
            continue
        
        files_dict[file_] = score
            
        count += 1 
        
    return files_dict

files_dict = get_filenames()

# %%
"""
Create dictionary with:
Key = alias
Value = list of filenames for user
"""

DATASET_DIR = 'data_images'

def create_user_dict(dataset_dir):
    user_dict = {}
    
    for filename in os.listdir(dataset_dir):
        filename = filename.rsplit('.', 1)[0]
        alias = filename.rsplit('_', 1)[0]
        
        if alias not in user_dict:
            user_dict[alias] = [filename]
        else:
            user_dict[alias].append(filename)
            
    return user_dict

user_dict = create_user_dict(DATASET_DIR)

# %%
"""Split training and test images"""

PERCENT_TRAINING = 0.75 

random.seed(10)
keys = user_dict.keys()
split = int(len(user_dict.keys()) * PERCENT_TRAINING)

random.shuffle(keys) # revisit this shuffle function

train_users = keys[:split]
test_users = keys[split:]

train_keys = []
test_keys = []

for user in train_users:
    for filename in user_dict[user]:
        train_keys.append(filename)
        
for user in test_users:
    for filename in user_dict[user]:
        test_keys.append(filename)

# %%
def chunks(l, n):
    """Yield successive n-sized chunks from l"""
    for i in xrange(0, len(l), n):
        yield l[i:i+n]

def get_train_data(chunk, img_row, img_col):
    X_train = []
    Y_train = []
    
    for imgname in chunk:
        try:
            filename = 'data_images'+'/'+imgname+'.png'
            img = cv2.imread(filename)
            img = cv2.resize(img,(img_row,img_col))
            X_train.append(img)
            Y_train.append(files_dict[imgname])
        except: 
            continue
    X_train = np.asarray(X_train)
    Y_train = np.asarray(Y_train)

    return X_train,Y_train
    
def get_test_data(chunk, img_row, img_col):
    X_test = []
    Y_test = []
    
    for imgname in chunk:
        try:
            filename = './data_images'+'/'+imgname+'.png'
            img = cv2.imread(filename)
            img = cv2.resize(img,(img_row,img_col))
            X_test.append(img)
            Y_test.append(files_dict[imgname])
        except:
            continue
    X_test = np.asarray(X_test)
    Y_test = np.asarray(Y_test)

    return X_test,Y_test

def getTrainData(chunk,img_rows,img_cols):
    X_train,Y_train = get_train_data(chunk,img_rows,img_cols)
    if (X_train is not None and Y_train is not None):
        X_train/=255
    return (X_train,Y_train)

def getTestData(chunk,img_rows,img_cols):
    X_test,Y_test = get_test_data(chunk,img_rows,img_cols)
    if (X_test is not None and Y_test is not None):
        X_test/=255
    return (X_test,Y_test)

def test(model, nb_epoch, spatial_test_data, img_rows, img_cols):
    X_test,Y_test = getTestData(test_keys,img_rows,img_cols)
    return (X_test, Y_test)

# %%
num_epochs = 1
nb_epoch = 100
batch_size = 2
chunk_size = 32
img_rows = 160
img_cols = 160

# %%
for e in range(nb_epoch):
    print('-'*40)
    print 'Epoch', e
    print('-'*40)
    print "Training..."
    instance_count=0


    for chunk in chunks(train_keys, chunk_size):
        X_chunk,Y_chunk=getTrainData(chunk,img_rows,img_cols)

        if (X_chunk is not None and Y_chunk is not None):
            loss = custom_model.fit(X_chunk, Y_chunk, verbose=1, batch_size=batch_size, epochs=num_epochs)
            instance_count+=chunk_size
            
            print "Instance Count:", instance_count
            
            if instance_count%100==0:
                custom_model.save_weights('basic_model.h5',overwrite=True)
# Out:
# ----------------------------------------
# Epoch 0
# ----------------------------------------
# Training...
# Epoch 1/1
# 32/32 [==============================] - 2s - loss: 7.5355 - acc: 0.0938
# Instance Count: 32
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 3.5477 - acc: 0.0000e+00
# Instance Count: 64
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.7021 - acc: 0.0312
# Instance Count: 96
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.8820 - acc: 0.0938
# Instance Count: 128
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.9270 - acc: 0.1250
# Instance Count: 160
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.5221 - acc: 0.0938
# Instance Count: 192
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2914 - acc: 0.1562
# Instance Count: 224
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2146 - acc: 0.1250
# Instance Count: 256
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1717 - acc: 0.0000e+00
# Instance Count: 288
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1482 - acc: 0.1250
# Instance Count: 320
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1935 - acc: 0.1562
# Instance Count: 352
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1978 - acc: 0.0938
# Instance Count: 384
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.4757 - acc: 0.0938
# Instance Count: 416
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1516 - acc: 0.0625
# Instance Count: 448
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1375 - acc: 0.1875
# Instance Count: 480
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1589 - acc: 0.0938
# Instance Count: 512
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1564 - acc: 0.1250
# Instance Count: 544
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.3867 - acc: 0.0000e+00
# Instance Count: 576
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2258 - acc: 0.0625
# Instance Count: 608
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1560 - acc: 0.0938
# Instance Count: 640
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1721 - acc: 0.1562
# Instance Count: 672
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1115 - acc: 0.1250
# Instance Count: 704
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1682 - acc: 0.0312
# Instance Count: 736
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1196 - acc: 0.1562
# Instance Count: 768
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1293 - acc: 0.0938
# Instance Count: 800
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1351 - acc: 0.1562
# Instance Count: 832
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1179 - acc: 0.1250
# Instance Count: 864
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1711 - acc: 0.1562
# Instance Count: 896
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1173 - acc: 0.1250
# Instance Count: 928
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1419 - acc: 0.1250
# Instance Count: 960
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2181 - acc: 0.0938
# Instance Count: 992
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0930 - acc: 0.1250
# Instance Count: 1024
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0833 - acc: 0.0312
# Instance Count: 1056
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0994 - acc: 0.1250
# Instance Count: 1088
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1026 - acc: 0.1562
# Instance Count: 1120
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1190 - acc: 0.1562
# Instance Count: 1152
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1190 - acc: 0.1875
# Instance Count: 1184
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1128 - acc: 0.1250
# Instance Count: 1216
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2760 - acc: 0.0625
# Instance Count: 1248
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1020 - acc: 0.0625
# Instance Count: 1280
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.6207 - acc: 0.1562
# Instance Count: 1312
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1189 - acc: 0.0938
# Instance Count: 1344
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1494 - acc: 0.0938
# Instance Count: 1376
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1056 - acc: 0.0625
# Instance Count: 1408
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1137 - acc: 0.1562
# Instance Count: 1440
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2502 - acc: 0.2188
# Instance Count: 1472
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1267 - acc: 0.0938
# Instance Count: 1504
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1109 - acc: 0.0625
# Instance Count: 1536
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0899 - acc: 0.0625
# Instance Count: 1568
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1035 - acc: 0.1562
# Instance Count: 1600
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1517 - acc: 0.3750
# Instance Count: 1632
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1126 - acc: 0.1562
# Instance Count: 1664
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1407 - acc: 0.0938
# Instance Count: 1696
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1209 - acc: 0.1875
# Instance Count: 1728
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1444 - acc: 0.1562
# Instance Count: 1760
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0887 - acc: 0.0625
# Instance Count: 1792
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1080 - acc: 0.0625
# Instance Count: 1824
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1256 - acc: 0.1562
# Instance Count: 1856
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0715 - acc: 0.0938
# Instance Count: 1888
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1203 - acc: 0.1562
# Instance Count: 1920
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1235 - acc: 0.0938
# Instance Count: 1952
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0772 - acc: 0.0312
# Instance Count: 1984
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1156 - acc: 0.1250
# Instance Count: 2016
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1071 - acc: 0.0938
# Instance Count: 2048
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1312 - acc: 0.1562
# Instance Count: 2080
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1281 - acc: 0.0312
# Instance Count: 2112
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0958 - acc: 0.0625
# Instance Count: 2144
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0847 - acc: 0.0938
# Instance Count: 2176
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0922 - acc: 0.1562
# Instance Count: 2208
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1182 - acc: 0.1250
# Instance Count: 2240
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1246 - acc: 0.0625
# Instance Count: 2272
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0829 - acc: 0.0625
# Instance Count: 2304
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1256 - acc: 0.1250
# Instance Count: 2336
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0799 - acc: 0.0625
# Instance Count: 2368
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0676 - acc: 0.0312
# Instance Count: 2400
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1180 - acc: 0.0000e+00
# Instance Count: 2432
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0918 - acc: 0.1250
# Instance Count: 2464
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0838 - acc: 0.1250
# Instance Count: 2496
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0891 - acc: 0.1250
# Instance Count: 2528
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1089 - acc: 0.1562
# Instance Count: 2560
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0967 - acc: 0.1250
# Instance Count: 2592
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2085 - acc: 0.1250
# Instance Count: 2624
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0770 - acc: 0.0625
# Instance Count: 2656
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2774 - acc: 0.0938
# Instance Count: 2688
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1085 - acc: 0.0625
# Instance Count: 2720
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1301 - acc: 0.1250
# Instance Count: 2752
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0955 - acc: 0.0938
# Instance Count: 2784
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0979 - acc: 0.1875
# Instance Count: 2816
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1152 - acc: 0.1250
# Instance Count: 2848
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0947 - acc: 0.1250
# Instance Count: 2880
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1283 - acc: 0.1250
# Instance Count: 2912
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1129 - acc: 0.1562
# Instance Count: 2944
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1053 - acc: 0.1562
# Instance Count: 2976
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0936 - acc: 0.0625
# Instance Count: 3008
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1036 - acc: 0.2188
# Instance Count: 3040
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1143 - acc: 0.0625
# Instance Count: 3072
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1080 - acc: 0.0938
# Instance Count: 3104
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0997 - acc: 0.0625
# Instance Count: 3136
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1169 - acc: 0.0938
# Instance Count: 3168
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1401 - acc: 0.1875
# Instance Count: 3200
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0960 - acc: 0.0625
# Instance Count: 3232
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1198 - acc: 0.0938
# Instance Count: 3264
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1254 - acc: 0.0938
# Instance Count: 3296
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1140 - acc: 0.0938
# Instance Count: 3328
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1123 - acc: 0.0938
# Instance Count: 3360
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1181 - acc: 0.1562
# Instance Count: 3392
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0988 - acc: 0.1250
# Instance Count: 3424
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1254 - acc: 0.0312
# Instance Count: 3456
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1306 - acc: 0.5625
# Instance Count: 3488
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1442 - acc: 0.1562
# Instance Count: 3520
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1060 - acc: 0.1562
# Instance Count: 3552
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1201 - acc: 0.1562
# Instance Count: 3584
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0849 - acc: 0.1562
# Instance Count: 3616
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1236 - acc: 0.1562
# Instance Count: 3648
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0979 - acc: 0.1250
# Instance Count: 3680
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1119 - acc: 0.1562
# Instance Count: 3712
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1995 - acc: 0.2500
# Instance Count: 3744
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0755 - acc: 0.0312
# Instance Count: 3776
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1271 - acc: 0.0312
# Instance Count: 3808
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1266 - acc: 0.0625
# Instance Count: 3840
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0874 - acc: 0.1562
# Instance Count: 3872
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1176 - acc: 0.1875
# Instance Count: 3904
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1217 - acc: 0.0312
# Instance Count: 3936
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1211 - acc: 0.1562
# Instance Count: 3968
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0932 - acc: 0.1562
# Instance Count: 4000
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1166 - acc: 0.1250
# Instance Count: 4032
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1086 - acc: 0.1562
# Instance Count: 4064
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1049 - acc: 0.1250
# Instance Count: 4096
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1303 - acc: 0.1250
# Instance Count: 4128
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2228 - acc: 0.1562
# Instance Count: 4160
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1102 - acc: 0.1250
# Instance Count: 4192
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0975 - acc: 0.1875
# Instance Count: 4224
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0921 - acc: 0.0938
# Instance Count: 4256
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1098 - acc: 0.0938
# Instance Count: 4288
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0908 - acc: 0.0625
# Instance Count: 4320
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1028 - acc: 0.0938
# Instance Count: 4352
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.3478 - acc: 0.1562
# Instance Count: 4384
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1323 - acc: 0.0625
# Instance Count: 4416
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1145 - acc: 0.0312
# Instance Count: 4448
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1125 - acc: 0.1875
# Instance Count: 4480
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1126 - acc: 0.1562
# Instance Count: 4512
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1139 - acc: 0.1562
# Instance Count: 4544
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1012 - acc: 0.1250
# Instance Count: 4576
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1160 - acc: 0.1562
# Instance Count: 4608
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1190 - acc: 0.1562
# Instance Count: 4640
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0985 - acc: 0.0938
# Instance Count: 4672
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0994 - acc: 0.1875
# Instance Count: 4704
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1021 - acc: 0.0938
# Instance Count: 4736
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0959 - acc: 0.0938
# Instance Count: 4768
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1155 - acc: 0.1875
# Instance Count: 4800
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1069 - acc: 0.1250
# Instance Count: 4832
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1068 - acc: 0.1875
# Instance Count: 4864
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1188 - acc: 0.1250
# Instance Count: 4896
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0985 - acc: 0.1250
# Instance Count: 4928
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1213 - acc: 0.0938
# Instance Count: 4960
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1104 - acc: 0.1250
# Instance Count: 4992
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1267 - acc: 0.0625
# Instance Count: 5024
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1102 - acc: 0.2500
# Instance Count: 5056
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2055 - acc: 0.0625
# Instance Count: 5088
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1185 - acc: 0.0938
# Instance Count: 5120
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1057 - acc: 0.1250
# Instance Count: 5152
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1139 - acc: 0.1875
# Instance Count: 5184
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1169 - acc: 0.0625
# Instance Count: 5216
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1032 - acc: 0.0625
# Instance Count: 5248
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1406 - acc: 0.0938
# Instance Count: 5280
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0952 - acc: 0.1250
# Instance Count: 5312
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1279 - acc: 0.0938
# Instance Count: 5344
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1101 - acc: 0.1875
# Instance Count: 5376
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1101 - acc: 0.1250
# Instance Count: 5408
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1078 - acc: 0.1250
# Instance Count: 5440
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1354 - acc: 0.1250
# Instance Count: 5472
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1039 - acc: 0.1250
# Instance Count: 5504
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1320 - acc: 0.0938
# Instance Count: 5536
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0967 - acc: 0.1875
# Instance Count: 5568
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1221 - acc: 0.1562
# Instance Count: 5600
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1076 - acc: 0.0312
# Instance Count: 5632
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1103 - acc: 0.0938
# Instance Count: 5664
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0669 - acc: 0.0625
# Instance Count: 5696
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0830 - acc: 0.0938
# Instance Count: 5728
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0939 - acc: 0.1250
# Instance Count: 5760
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0923 - acc: 0.0938
# Instance Count: 5792
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0997 - acc: 0.1562
# Instance Count: 5824
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1073 - acc: 0.1562
# Instance Count: 5856
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0979 - acc: 0.1562
# Instance Count: 5888
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0882 - acc: 0.0938
# Instance Count: 5920
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1132 - acc: 0.1562
# Instance Count: 5952
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1186 - acc: 0.1250
# Instance Count: 5984
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1045 - acc: 0.1562
# Instance Count: 6016
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1080 - acc: 0.1250
# Instance Count: 6048
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1113 - acc: 0.1562
# Instance Count: 6080
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1015 - acc: 0.1562
# Instance Count: 6112
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1007 - acc: 0.0625
# Instance Count: 6144
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0940 - acc: 0.0625
# Instance Count: 6176
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0933 - acc: 0.0625
# Instance Count: 6208
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1059 - acc: 0.1250
# Instance Count: 6240
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1093 - acc: 0.0625
# Instance Count: 6272
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1111 - acc: 0.1250
# Instance Count: 6304
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1004 - acc: 0.0938
# Instance Count: 6336
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0947 - acc: 0.1562
# Instance Count: 6368
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1018 - acc: 0.1875
# Instance Count: 6400
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1145 - acc: 0.1562
# Instance Count: 6432
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1145 - acc: 0.0938
# Instance Count: 6464
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0872 - acc: 0.0312
# Instance Count: 6496
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1220 - acc: 0.1562
# Instance Count: 6528
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1096 - acc: 0.1562
# Instance Count: 6560
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0723 - acc: 0.0312
# Instance Count: 6592
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1077 - acc: 0.1562
# Instance Count: 6624
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1223 - acc: 0.1250
# Instance Count: 6656
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1173 - acc: 0.1875
# Instance Count: 6688
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0766 - acc: 0.0312
# Instance Count: 6720
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1098 - acc: 0.1250
# Instance Count: 6752
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1099 - acc: 0.2188
# Instance Count: 6784
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1084 - acc: 0.0625
# Instance Count: 6816
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1381 - acc: 0.5000
# Instance Count: 6848
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1298 - acc: 0.1875
# Instance Count: 6880
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1274 - acc: 0.1875
# Instance Count: 6912
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0944 - acc: 0.2188
# Instance Count: 6944
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1246 - acc: 0.1250
# Instance Count: 6976
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0968 - acc: 0.1562
# Instance Count: 7008
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1165 - acc: 0.0938
# Instance Count: 7040
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0880 - acc: 0.1562
# Instance Count: 7072
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1187 - acc: 0.2188
# Instance Count: 7104
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1116 - acc: 0.1250
# Instance Count: 7136
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1092 - acc: 0.1250
# Instance Count: 7168
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1293 - acc: 0.1562
# Instance Count: 7200
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0959 - acc: 0.0625
# Instance Count: 7232
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0908 - acc: 0.0625
# Instance Count: 7264
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1016 - acc: 0.0625
# Instance Count: 7296
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1034 - acc: 0.0938
# Instance Count: 7328
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1327 - acc: 0.1562
# Instance Count: 7360
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1047 - acc: 0.0625
# Instance Count: 7392
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1182 - acc: 0.0625
# Instance Count: 7424
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1054 - acc: 0.0625
# Instance Count: 7456
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1003 - acc: 0.1875
# Instance Count: 7488
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0984 - acc: 0.0938
# Instance Count: 7520
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1174 - acc: 0.0625
# Instance Count: 7552
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1136 - acc: 0.1562
# Instance Count: 7584
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2140 - acc: 0.1250
# Instance Count: 7616
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1305 - acc: 0.0000e+00
# Instance Count: 7648
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1122 - acc: 0.0625
# Instance Count: 7680
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0934 - acc: 0.0938
# Instance Count: 7712
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1093 - acc: 0.1562
# Instance Count: 7744
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1048 - acc: 0.1562
# Instance Count: 7776
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0986 - acc: 0.1562
# Instance Count: 7808
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0779 - acc: 0.0938
# Instance Count: 7840
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1010 - acc: 0.0625
# Instance Count: 7872
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1021 - acc: 0.0938
# Instance Count: 7904
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1045 - acc: 0.0625
# Instance Count: 7936
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1246 - acc: 0.1875
# Instance Count: 7968
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0930 - acc: 0.0938
# Instance Count: 8000
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1126 - acc: 0.1250
# Instance Count: 8032
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1328 - acc: 0.1562
# Instance Count: 8064
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1120 - acc: 0.1562
# Instance Count: 8096
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0901 - acc: 0.0312
# Instance Count: 8128
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0897 - acc: 0.1250
# Instance Count: 8160
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1104 - acc: 0.1562
# Instance Count: 8192
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1238 - acc: 0.1562
# Instance Count: 8224
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1024 - acc: 0.1250
# Instance Count: 8256
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1072 - acc: 0.1250
# Instance Count: 8288
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1153 - acc: 0.1562
# Instance Count: 8320
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0776 - acc: 0.0938
# Instance Count: 8352
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0907 - acc: 0.1250
# Instance Count: 8384
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0982 - acc: 0.0938
# Instance Count: 8416
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1068 - acc: 0.0312
# Instance Count: 8448
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0968 - acc: 0.1250
# Instance Count: 8480
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1026 - acc: 0.1562
# Instance Count: 8512
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0941 - acc: 0.0938
# Instance Count: 8544
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1255 - acc: 0.1250
# Instance Count: 8576
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1140 - acc: 0.1875
# Instance Count: 8608
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1137 - acc: 0.1875
# Instance Count: 8640
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1391 - acc: 0.1250
# Instance Count: 8672
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1157 - acc: 0.0938
# Instance Count: 8704
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0868 - acc: 0.1250
# Instance Count: 8736
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1156 - acc: 0.0938
# Instance Count: 8768
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1025 - acc: 0.0938
# Instance Count: 8800
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1054 - acc: 0.1250
# Instance Count: 8832
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1160 - acc: 0.1562
# Instance Count: 8864
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1275 - acc: 0.1250
# Instance Count: 8896
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1093 - acc: 0.1562
# Instance Count: 8928
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1081 - acc: 0.1875
# Instance Count: 8960
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0597 - acc: 0.0312
# Instance Count: 8992
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1084 - acc: 0.0625
# Instance Count: 9024
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1087 - acc: 0.1562
# Instance Count: 9056
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1347 - acc: 0.1250
# Instance Count: 9088
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1099 - acc: 0.0312
# Instance Count: 9120
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0941 - acc: 0.1250
# Instance Count: 9152
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1159 - acc: 0.1875
# Instance Count: 9184
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1287 - acc: 0.1250
# Instance Count: 9216
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1293 - acc: 0.2188
# Instance Count: 9248
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1053 - acc: 0.0625
# Instance Count: 9280
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0919 - acc: 0.0938
# Instance Count: 9312
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0960 - acc: 0.1562
# Instance Count: 9344
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1041 - acc: 0.0938
# Instance Count: 9376
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0960 - acc: 0.0938
# Instance Count: 9408
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1089 - acc: 0.1562
# Instance Count: 9440
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0936 - acc: 0.1562
# Instance Count: 9472
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1047 - acc: 0.1562
# Instance Count: 9504
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0859 - acc: 0.0938
# Instance Count: 9536
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1145 - acc: 0.0938
# Instance Count: 9568
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1244 - acc: 0.0625
# Instance Count: 9600
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1729 - acc: 0.1562
# Instance Count: 9632
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1186 - acc: 0.0938
# Instance Count: 9664
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0975 - acc: 0.2188
# Instance Count: 9696
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1169 - acc: 0.1875
# Instance Count: 9728
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1022 - acc: 0.0625
# Instance Count: 9760
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1194 - acc: 0.0000e+00
# Instance Count: 9792
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1191 - acc: 0.1250
# Instance Count: 9824
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1128 - acc: 0.1562
# Instance Count: 9856
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1027 - acc: 0.1562
# Instance Count: 9888
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1296 - acc: 0.1562
# Instance Count: 9920
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0946 - acc: 0.1250
# Instance Count: 9952
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1153 - acc: 0.1562
# Instance Count: 9984
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.3303 - acc: 0.1562
# Instance Count: 10016
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1039 - acc: 0.1250
# Instance Count: 10048
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1036 - acc: 0.0625
# Instance Count: 10080
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1260 - acc: 0.0312
# Instance Count: 10112
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1299 - acc: 0.1875
# Instance Count: 10144
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1272 - acc: 0.0625
# Instance Count: 10176
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1131 - acc: 0.0938
# Instance Count: 10208
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1081 - acc: 0.0625
# Instance Count: 10240
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1302 - acc: 0.2188
# Instance Count: 10272
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0886 - acc: 0.1250
# Instance Count: 10304
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1184 - acc: 0.1562
# Instance Count: 10336
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0981 - acc: 0.1250
# Instance Count: 10368
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0991 - acc: 0.0625
# Instance Count: 10400
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1080 - acc: 0.1250
# Instance Count: 10432
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0756 - acc: 0.1250
# Instance Count: 10464
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0973 - acc: 0.0938
# Instance Count: 10496
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1070 - acc: 0.0938
# Instance Count: 10528
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1079 - acc: 0.0000e+00
# Instance Count: 10560
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1044 - acc: 0.0312
# Instance Count: 10592
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1050 - acc: 0.1250
# Instance Count: 10624
# Epoch 1/1
# 2/2 [==============================] - 0s - loss: 0.0918 - acc: 0.0000e+00
# Instance Count: 10656
# ----------------------------------------
# Epoch 1
# ----------------------------------------
# Training...
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1154 - acc: 0.1250
# Instance Count: 32
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1386 - acc: 0.0938
# Instance Count: 64
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1254 - acc: 0.1562
# Instance Count: 96
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1136 - acc: 0.2188
# Instance Count: 128
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1828 - acc: 0.1875
# Instance Count: 160
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1520 - acc: 0.0938
# Instance Count: 192
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1055 - acc: 0.1562
# Instance Count: 224
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0971 - acc: 0.1250
# Instance Count: 256
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1001 - acc: 0.0625
# Instance Count: 288
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1148 - acc: 0.1250
# Instance Count: 320
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1040 - acc: 0.1875
# Instance Count: 352
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1120 - acc: 0.1250
# Instance Count: 384
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1275 - acc: 0.1250
# Instance Count: 416
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1042 - acc: 0.0625
# Instance Count: 448
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1152 - acc: 0.2188
# Instance Count: 480
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0902 - acc: 0.0938
# Instance Count: 512
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1180 - acc: 0.1250
# Instance Count: 544
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2059 - acc: 0.0625
# Instance Count: 576
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1496 - acc: 0.1250
# Instance Count: 608
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1808 - acc: 0.0625
# Instance Count: 640
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.2294 - acc: 0.0625
# Instance Count: 672
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1011 - acc: 0.1250
# Instance Count: 704
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1248 - acc: 0.0938
# Instance Count: 736
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1048 - acc: 0.1250
# Instance Count: 768
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0979 - acc: 0.0938
# Instance Count: 800
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1019 - acc: 0.1250
# Instance Count: 832
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1101 - acc: 0.1250
# Instance Count: 864
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.3283 - acc: 0.1562
# Instance Count: 896
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1335 - acc: 0.0625
# Instance Count: 928
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1193 - acc: 0.0938
# Instance Count: 960
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1152 - acc: 0.1250
# Instance Count: 992
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.3141 - acc: 0.1250
# Instance Count: 1024
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0932 - acc: 0.0312
# Instance Count: 1056
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1024 - acc: 0.1250
# Instance Count: 1088
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1029 - acc: 0.1562
# Instance Count: 1120
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1084 - acc: 0.1875
# Instance Count: 1152
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1140 - acc: 0.1562
# Instance Count: 1184
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1112 - acc: 0.1562
# Instance Count: 1216
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1126 - acc: 0.0625
# Instance Count: 1248
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0946 - acc: 0.0625
# Instance Count: 1280
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0971 - acc: 0.2188
# Instance Count: 1312
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1265 - acc: 0.0312
# Instance Count: 1344
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1063 - acc: 0.0625
# Instance Count: 1376
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0918 - acc: 0.0938
# Instance Count: 1408
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1037 - acc: 0.1250
# Instance Count: 1440
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1245 - acc: 0.1562
# Instance Count: 1472
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0854 - acc: 0.0938
# Instance Count: 1504
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1017 - acc: 0.0938
# Instance Count: 1536
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0996 - acc: 0.0312
# Instance Count: 1568
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1017 - acc: 0.0938
# Instance Count: 1600
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1500 - acc: 0.4688
# Instance Count: 1632
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0982 - acc: 0.1875
# Instance Count: 1664
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1194 - acc: 0.0938
# Instance Count: 1696
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1169 - acc: 0.1875
# Instance Count: 1728
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1317 - acc: 0.1562
# Instance Count: 1760
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0883 - acc: 0.0625
# Instance Count: 1792
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1070 - acc: 0.0625
# Instance Count: 1824
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1253 - acc: 0.1562
# Instance Count: 1856
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0766 - acc: 0.0938
# Instance Count: 1888
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1243 - acc: 0.1875
# Instance Count: 1920
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1119 - acc: 0.1250
# Instance Count: 1952
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0709 - acc: 0.0312
# Instance Count: 1984
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1165 - acc: 0.1250
# Instance Count: 2016
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0986 - acc: 0.0938
# Instance Count: 2048
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1170 - acc: 0.1562
# Instance Count: 2080
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0811 - acc: 0.0625
# Instance Count: 2112
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0994 - acc: 0.0625
# Instance Count: 2144
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0705 - acc: 0.0938
# Instance Count: 2176
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0944 - acc: 0.1875
# Instance Count: 2208
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1137 - acc: 0.1250
# Instance Count: 2240
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1146 - acc: 0.0625
# Instance Count: 2272
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1162 - acc: 0.0938
# Instance Count: 2304
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1209 - acc: 0.1562
# Instance Count: 2336
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0880 - acc: 0.0312
# Instance Count: 2368
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0686 - acc: 0.0625
# Instance Count: 2400
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1125 - acc: 0.0625
# Instance Count: 2432
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0863 - acc: 0.1250
# Instance Count: 2464
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0879 - acc: 0.1250
# Instance Count: 2496
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0939 - acc: 0.1250
# Instance Count: 2528
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1323 - acc: 0.1562
# Instance Count: 2560
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0993 - acc: 0.0625
# Instance Count: 2592
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1871 - acc: 0.1562
# Instance Count: 2624
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1116 - acc: 0.0625
# Instance Count: 2656
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1100 - acc: 0.1250
# Instance Count: 2688
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1033 - acc: 0.0312
# Instance Count: 2720
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1329 - acc: 0.1562
# Instance Count: 2752
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0889 - acc: 0.0938
# Instance Count: 2784
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0996 - acc: 0.1250
# Instance Count: 2816
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1070 - acc: 0.1562
# Instance Count: 2848
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0961 - acc: 0.1250
# Instance Count: 2880
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1375 - acc: 0.1250
# Instance Count: 2912
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1127 - acc: 0.1250
# Instance Count: 2944
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1090 - acc: 0.1875
# Instance Count: 2976
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0920 - acc: 0.0312
# Instance Count: 3008
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1235 - acc: 0.0938
# Instance Count: 3040
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1087 - acc: 0.0938
# Instance Count: 3072
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1082 - acc: 0.1562
# Instance Count: 3104
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0951 - acc: 0.0625
# Instance Count: 3136
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1249 - acc: 0.0938
# Instance Count: 3168
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1183 - acc: 0.2500
# Instance Count: 3200
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0977 - acc: 0.0000e+00
# Instance Count: 3232
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1134 - acc: 0.0625
# Instance Count: 3264
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1289 - acc: 0.1250
# Instance Count: 3296
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1127 - acc: 0.1250
# Instance Count: 3328
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1113 - acc: 0.0938
# Instance Count: 3360
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1255 - acc: 0.1562
# Instance Count: 3392
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0942 - acc: 0.1250
# Instance Count: 3424
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1328 - acc: 0.0312
# Instance Count: 3456
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1232 - acc: 0.5625
# Instance Count: 3488
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1417 - acc: 0.1562
# Instance Count: 3520
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1098 - acc: 0.1562
# Instance Count: 3552
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1306 - acc: 0.1562
# Instance Count: 3584
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0824 - acc: 0.1562
# Instance Count: 3616
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1246 - acc: 0.1562
# Instance Count: 3648
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0967 - acc: 0.1250
# Instance Count: 3680
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1152 - acc: 0.1562
# Instance Count: 3712
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1978 - acc: 0.1875
# Instance Count: 3744
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0740 - acc: 0.0312
# Instance Count: 3776
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1337 - acc: 0.0938
# Instance Count: 3808
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1130 - acc: 0.0625
# Instance Count: 3840
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0936 - acc: 0.1562
# Instance Count: 3872
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1083 - acc: 0.2188
# Instance Count: 3904
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1074 - acc: 0.0625
# Instance Count: 3936
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1141 - acc: 0.2500
# Instance Count: 3968
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0890 - acc: 0.0938
# Instance Count: 4000
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1148 - acc: 0.1250
# Instance Count: 4032
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1044 - acc: 0.1562
# Instance Count: 4064
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1070 - acc: 0.0938
# Instance Count: 4096
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1209 - acc: 0.1562
# Instance Count: 4128
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1115 - acc: 0.1562
# Instance Count: 4160
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1067 - acc: 0.1250
# Instance Count: 4192
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0983 - acc: 0.1875
# Instance Count: 4224
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0938 - acc: 0.0938
# Instance Count: 4256
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1076 - acc: 0.1250
# Instance Count: 4288
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0902 - acc: 0.0625
# Instance Count: 4320
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1097 - acc: 0.0625
# Instance Count: 4352
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1067 - acc: 0.1562
# Instance Count: 4384
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1167 - acc: 0.1250
# Instance Count: 4416
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1193 - acc: 0.0938
# Instance Count: 4448
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1185 - acc: 0.2500
# Instance Count: 4480
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1414 - acc: 0.1250
# Instance Count: 4512
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1176 - acc: 0.1562
# Instance Count: 4544
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0968 - acc: 0.1250
# Instance Count: 4576
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1780 - acc: 0.1562
# Instance Count: 4608
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1126 - acc: 0.1562
# Instance Count: 4640
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0997 - acc: 0.0938
# Instance Count: 4672
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 3.4609 - acc: 0.1250
# Instance Count: 4704
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0976 - acc: 0.0938
# Instance Count: 4736
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1160 - acc: 0.0312
# Instance Count: 4768
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1111 - acc: 0.1250
# Instance Count: 4800
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1068 - acc: 0.1250
# Instance Count: 4832
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1005 - acc: 0.1875
# Instance Count: 4864
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1121 - acc: 0.1250
# Instance Count: 4896
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0987 - acc: 0.1250
# Instance Count: 4928
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1177 - acc: 0.0938
# Instance Count: 4960
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1047 - acc: 0.1562
# Instance Count: 4992
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1053 - acc: 0.0938
# Instance Count: 5024
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1083 - acc: 0.2812
# Instance Count: 5056
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1114 - acc: 0.1250
# Instance Count: 5088
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1146 - acc: 0.0938
# Instance Count: 5120
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1142 - acc: 0.1250
# Instance Count: 5152
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1070 - acc: 0.1562
# Instance Count: 5184
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1043 - acc: 0.0312
# Instance Count: 5216
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0978 - acc: 0.0938
# Instance Count: 5248
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1192 - acc: 0.0938
# Instance Count: 5280
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0915 - acc: 0.1250
# Instance Count: 5312
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1261 - acc: 0.0938
# Instance Count: 5344
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1123 - acc: 0.1875
# Instance Count: 5376
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1155 - acc: 0.1250
# Instance Count: 5408
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1127 - acc: 0.1250
# Instance Count: 5440
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1200 - acc: 0.1562
# Instance Count: 5472
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0968 - acc: 0.1250
# Instance Count: 5504
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1275 - acc: 0.0938
# Instance Count: 5536
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0987 - acc: 0.1875
# Instance Count: 5568
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1232 - acc: 0.1562
# Instance Count: 5600
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1001 - acc: 0.0938
# Instance Count: 5632
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1092 - acc: 0.0938
# Instance Count: 5664
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0638 - acc: 0.0625
# Instance Count: 5696
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0911 - acc: 0.0938
# Instance Count: 5728
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0958 - acc: 0.1250
# Instance Count: 5760
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0928 - acc: 0.0938
# Instance Count: 5792
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0976 - acc: 0.1875
# Instance Count: 5824
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0989 - acc: 0.1562
# Instance Count: 5856
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0900 - acc: 0.1562
# Instance Count: 5888
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0908 - acc: 0.0625
# Instance Count: 5920
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1217 - acc: 0.1562
# Instance Count: 5952
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1177 - acc: 0.1250
# Instance Count: 5984
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1016 - acc: 0.1562
# Instance Count: 6016
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0974 - acc: 0.1250
# Instance Count: 6048
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1007 - acc: 0.1562
# Instance Count: 6080
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0957 - acc: 0.1562
# Instance Count: 6112
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1023 - acc: 0.0625
# Instance Count: 6144
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0884 - acc: 0.0625
# Instance Count: 6176
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0894 - acc: 0.0938
# Instance Count: 6208
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1151 - acc: 0.1250
# Instance Count: 6240
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1111 - acc: 0.0625
# Instance Count: 6272
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1192 - acc: 0.1250
# Instance Count: 6304
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1026 - acc: 0.1250
# Instance Count: 6336
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0896 - acc: 0.1562
# Instance Count: 6368
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0967 - acc: 0.1875
# Instance Count: 6400
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1087 - acc: 0.1875
# Instance Count: 6432
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1178 - acc: 0.0625
# Instance Count: 6464
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0963 - acc: 0.0312
# Instance Count: 6496
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1205 - acc: 0.1875
# Instance Count: 6528
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1081 - acc: 0.1562
# Instance Count: 6560
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0712 - acc: 0.0312
# Instance Count: 6592
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1112 - acc: 0.1250
# Instance Count: 6624
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1191 - acc: 0.1562
# Instance Count: 6656
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.1169 - acc: 0.1875
# Instance Count: 6688
# Epoch 1/1
# 32/32 [==============================] - 3s - loss: 0.0767 - acc: 0.0312
# Instance Count: 6720
# Epoch 1/1
# 30/32 [===========================>..] - ETA: 0s - loss: 0.1014 - acc: 0.1333

# %% [markdown]
# ## Load Weights

# %%
weights_path = 'basic_model.h5'

if weights_path:
    custom_model.load_weights(weights_path)

# %%
""" SUDO CODE FOR CUSTOM ACCURACY FUNCTION"""

DATASET_DIR = 'data_images'

def test_accuracy():
    count = 0
    accuracy = 0
    
    for user in test_users:
        user_imgs = user_dict[user]
        
        if len(user_imgs) > 1:
           # get two elements from shuffled dictionary
            element1 = user_imgs.pop(0)
            element2 = user_imgs.pop(1)
            
            # read images
            img1 = cv2.imread(os.path.join(DATASET_DIR, element1+'.png'))
            img2 = cv2.imread(os.path.join(DATASET_DIR, element2+'.png'))
            
            #resize images
            img1 = cv2.resize(img1,(img_rows,img_cols))
            img2 = cv2.resize(img2,(img_rows,img_cols))
            
            # expand dimension
            img1 = np.expand_dims(img1, axis=0)
            img2 = np.expand_dims(img2, axis=0)
        
            # predict score for each image
            predict1 = np.argmax(custom_model.predict(img1))
            predict2 = np.argmax(custom_model.predict(img2))
            
            # compare whichever predicted score is higher
            
            # comparison dict
            if predict1 > predict2:
                max_predict = 'a'
            elif predict1 < predict2:
                max_predict = 'b'
            else:
                max_predict = 'equal'
            
            # compare whichever "score" is higher
            if files_dict[element1] > files_dict[element2]:
                max_actual = 'a'
            elif files_dict[element1] < files_dict[element2]:
                max_actual = 'b'
            else:
                max_actual = 'equal'

            # check if comparisons match 
            if max_predict == max_actual:
                accuracy +=1

            count += 1
            
            print max_predict
            print max_actual
            print max_predict == max_actual
            print '\n'
            
        else:
            continue
    
    accuracy_per = accuracy / count
    
    print count, "comparisons made"
    print "Accuracy score is:", accuracy_per
    
    return

test_accuracy()

# %% [markdown]
# ## Predict Test

# %%
img_name = 'cutegirlshairstyles_7'

img = cv2.imread('data_images/'+img_name+'.png')
img = cv2.resize(img,(160,160))
img = np.expand_dims(img, axis=0)

print custom_model.predict(img)
# Out:
# [[ 0.42518246]]
